# %%
# !wget https://us-east-2-scprojectdata.s3.us-east-2.amazonaws.com/p6mouse/patterns_anndata.h5ad

# %%
import random
random.seed(a=613)
import numpy as np
import scProject
import scanpy as sc
patterns = sc.read_h5ad('patterns_anndata.h5ad')
dataset = sc.read_h5ad('test_target.h5ad')
dataset_filtered, patterns_filtered = scProject.matcher.filterAnnDatas(dataset, patterns, 'gene_id')

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']= [10, 12]
scProject.rg.NNLR_ElasticNet(dataset_filtered, patterns_filtered, 'D3201', .0001, .01)
scProject.viz.pearsonMatrix(dataset_filtered, patterns_filtered, 'CellType', 12, 'D3201', 'D3201Pears', True)
# Out:
# (55371, 428) dataset filter shape
# (80, 428) patterns filter shape
# Trying to set attribute `.X` of view, copying.
# Trying to set attribute `.X` of view, copying.
# (55371, 80)
# [DARPP-32 cells, Excitatory Neurons, Astrocyte/Radial Glia, Oligodendrocyte, Vascular Endothelium, ..., Cycling Neural Progenitor, Brain Fibroblasts, Unknown, Microglia, Vascular Smooth Muscle]
# Length: 12
# Categories (12, object): [DARPP-32 cells, Excitatory Neurons, Astrocyte/Radial Glia, Oligodendrocyte, ..., Brain Fibroblasts, Unknown, Microglia, Vascular Smooth Muscle]

# %%
plt.rcParams['figure.figsize']= [12, 10]
scProject.viz.UMAP_Projection(dataset_filtered, 'CellType', 'D3201', 'UMAPD3201', 20)
# Out:
# [DARPP-32 cells, Excitatory Neurons, Astrocyte/Radial Glia, Oligodendrocyte, Vascular Endothelium, ..., Cycling Neural Progenitor, Brain Fibroblasts, Unknown, Microglia, Vascular Smooth Muscle]
# Length: 12
# Categories (12, object): [DARPP-32 cells, Excitatory Neurons, Astrocyte/Radial Glia, Oligodendrocyte, ..., Brain Fibroblasts, Unknown, Microglia, Vascular Smooth Muscle]

# %%
scProject.viz.featurePlots(dataset_filtered, 80, 'D3201', 'UMAPD3201', subset=['DARPP-32 cells'], obsColumn='CellType')
# Out:
# (479, 80)
# Number of nonzero cells 0
# Number of nonzero cells 0
# Number of nonzero cells 0
# Number of nonzero cells 5
# Number of nonzero cells 2
# Number of nonzero cells 18
# Number of nonzero cells 107
# Number of nonzero cells 46
# Number of nonzero cells 9
# Number of nonzero cells 14
# Number of nonzero cells 5
# Number of nonzero cells 242
# Number of nonzero cells 17
# Number of nonzero cells 13
# Number of nonzero cells 53
# Number of nonzero cells 98
# Number of nonzero cells 7
# Number of nonzero cells 8
# Number of nonzero cells 248
# Number of nonzero cells 1
# Number of nonzero cells 1
# Number of nonzero cells 41
# Number of nonzero cells 51
# Number of nonzero cells 3
# Number of nonzero cells 11
# Number of nonzero cells 260
# Number of nonzero cells 1
# Number of nonzero cells 0
# Number of nonzero cells 8
# Number of nonzero cells 3
# Number of nonzero cells 31
# Number of nonzero cells 1
# Number of nonzero cells 224
# Number of nonzero cells 11
# Number of nonzero cells 0
# Number of nonzero cells 272
# Number of nonzero cells 2
# Number of nonzero cells 188
# Number of nonzero cells 84
# Number of nonzero cells 2
# Number of nonzero cells 280
# Number of nonzero cells 13
# Number of nonzero cells 8
# Number of nonzero cells 3
# Number of nonzero cells 18
# Number of nonzero cells 4
# Number of nonzero cells 0
# Number of nonzero cells 3
# Number of nonzero cells 20
# Number of nonzero cells 1
# Number of nonzero cells 0
# Number of nonzero cells 62
# Number of nonzero cells 124
# Number of nonzero cells 31
# Number of nonzero cells 172
# Number of nonzero cells 6
# Number of nonzero cells 85
# Number of nonzero cells 112
# Number of nonzero cells 259
# Number of nonzero cells 21
# Number of nonzero cells 6
# Number of nonzero cells 11
# Number of nonzero cells 21
# Number of nonzero cells 4
# Number of nonzero cells 4
# Number of nonzero cells 4
# Number of nonzero cells 168
# Number of nonzero cells 18
# Number of nonzero cells 21
# Number of nonzero cells 164
# Number of nonzero cells 1
# Number of nonzero cells 11
# Number of nonzero cells 2
# Number of nonzero cells 3
# Number of nonzero cells 15
# Number of nonzero cells 0
# Number of nonzero cells 2
# Number of nonzero cells 9
# Number of nonzero cells 11
# Number of nonzero cells 4
